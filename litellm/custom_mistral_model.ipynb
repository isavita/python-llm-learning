# %%
# !pip install litellm
# Out:
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 7.2 MB/s eta 0:00:00m eta 0:00:010:01:01
# Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 6.7 MB/s eta 0:00:000:00:01
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.7/906.7 kB 7.3 MB/s eta 0:00:00m eta 0:00:010:01
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# ...

# %%
import os
from litellm import completion

response = completion(
    model="openai/mistral/ft:mistral-small-latest:8aad839f:20240616:b637638d",
    # model="openai/text-completion-mistral/codestral",
    messages=[{"role": "user", "content": "Hello, how are you?"}],
    # api_base="https://api.mistral.ai/v1/chat/completions"
)
print(response)
# Out:
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm.set_verbose=True'.
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# File ~/anaconda3/envs/mistral-env/lib/python3.12/site-packages/litellm/llms/openai.py:799, in OpenAIChatCompletion.completion(self, model_response, timeout, optional_params, model, messages, print_verbose, api_key, api_base, acompletion, logging_obj, litellm_params, logger_fn, headers, custom_prompt_dict, client, organization, custom_llm_provider)
#     798             else:
# --> 799                 raise e
#     800 except OpenAIError as e:
#
# ...
